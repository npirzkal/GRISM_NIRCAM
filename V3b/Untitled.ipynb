# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np

# %%
t = Table.read("/Users/npirzkal/Dropbox/GRISMDATA/NIRCAM/V3/NIRCam.F322W2.R.A.1st.sensitivity.fits")

# %%
plt.plot(t["WAVELENGTH"],t["SENSITIVITY"]/np.max(t["SENSITIVITY"]/0.35))
plt.grid()
#plt.ylim(0,0.52)
